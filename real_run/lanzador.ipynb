# %%
pip install amazon-braket-sdk numpy scipy scikit-learn pandas matplotlib
# Out:
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 67.7 MB/s  0:00:00
# ...
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 verify.py
# Out:
# Matplotlib is building the font cache; this may take a moment.
# tau_c = 10.30 tu | anchors = 66 (train 44 / test 22) | tol = 0.02
#   PASS  NG-RC deg2 alpha=1e-4 (roto)     obtenido -8.912  esperado -8.912
#   PASS  NG-RC deg2 RidgeCV (justo)       obtenido +0.405  esperado +0.405
#   PASS  NG-RC deg1 RidgeCV (lineal)      obtenido +0.706  esperado +0.706
#
# VERIFY OK: protocolo de evaluación consistente con la referencia.

# %%
# !python3 submit_aquila.py budget
# Out:
# ...
# CORRIDA ÚNICA AQUILA — diseño prerregistrado congelado
#   8 átomos | a=10.0 µm | Ω=6.283 rad/µs | Δ_i=4.5−9·x_i | readout Z
#   probes [0.5, 0.7, 1.8] µs | ts=1 | semilla 1234 | anchors 66
#   tareas: 66 × 3 = 198 | shots/tarea: 100
#   COSTO NOMINAL: 198 × ($0.3 + $0.01×100) = $257.40  (verificar tarifa vigente en la consola de AWS Braket)
# ...

# %%
# !python3 -m pip install amazon-braket-sdk

# %%
# !python3 submit_aquila.py real "AUTORIZO EL ENVÍO A AQUILA"
# Out:
# ...
# CORRIDA ÚNICA AQUILA — diseño prerregistrado congelado
#   8 átomos | a=10.0 µm | Ω=6.283 rad/µs | Δ_i=4.5−9·x_i | readout Z
#   probes [0.5, 0.7, 1.8] µs | ts=1 | semilla 1234 | anchors 66
#   tareas: 66 × 3 = 198 | shots/tarea: 100
#   COSTO NOMINAL: 198 × ($0.3 + $0.01×100) = $257.40  (verificar tarifa vigente en la consola de AWS Braket)
# ...
# [2026-07-12T02:51:28+00:00] REAL: dispositivo Aquila, status ONLINE
# [2026-07-12T02:51:29+00:00] SUBMITTED aquila_IV_s1234_tt0p5_a00 -> arn:aws:braket:us-east-1:<AWS-ACCOUNT-ID>:quantum-task/c0f95bfa-a675-44b6-97bc-e363c05e3460
# [2026-07-12T02:51:30+00:00] SUBMITTED aquila_IV_s1234_tt0p5_a01 -> arn:aws:braket:us-east-1:<AWS-ACCOUNT-ID>:quantum-task/b7687f8e-79e5-4739-aa4a-796cb3ae5e4e
# [2026-07-12T02:51:30+00:00] SUBMITTED aquila_IV_s1234_tt0p5_a02 -> arn:aws:braket:us-east-1:<AWS-ACCOUNT-ID>:quantum-task/cb63fbcd-ecdb-4ea5-867b-4c03251ce90f
# ...

# %%
# !python3 fetch_aquila.py
# Out:
# [2026-07-12T06:57:29+00:00] Tareas pendientes de descarga: 198
# [2026-07-12T06:57:29+00:00] DONE   aquila_IV_s1234_tt0p5_a00
# [2026-07-12T06:57:30+00:00] DONE   aquila_IV_s1234_tt0p5_a01
# [2026-07-12T06:57:30+00:00] DONE   aquila_IV_s1234_tt0p5_a02
# [2026-07-12T06:57:31+00:00] DONE   aquila_IV_s1234_tt0p5_a03
# [2026-07-12T06:57:31+00:00] DONE   aquila_IV_s1234_tt0p5_a04
# [2026-07-12T06:57:32+00:00] DONE   aquila_IV_s1234_tt0p5_a05
# [2026-07-12T06:57:32+00:00] DONE   aquila_IV_s1234_tt0p5_a06
# [2026-07-12T06:57:33+00:00] DONE   aquila_IV_s1234_tt0p5_a07
# [2026-07-12T06:57:33+00:00] DONE   aquila_IV_s1234_tt0p5_a08
# [2026-07-12T06:57:34+00:00] DONE   aquila_IV_s1234_tt0p5_a09
# [2026-07-12T06:57:35+00:00] DONE   aquila_IV_s1234_tt0p5_a10
# [2026-07-12T06:57:35+00:00] DONE   aquila_IV_s1234_tt0p5_a11
# [2026-07-12T06:57:36+00:00] DONE   aquila_IV_s1234_tt0p5_a12
# Task is in terminal state FAILED and no result is available.
# ...

# %%
# !python3 analyze_hardware.py real
# Out:
# AVISO: 1 tareas sin resultado (se computa con anchors disponibles, n efectivo declarado):
#   - aquila_IV_s1234_tt0p5_a13
# /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ...

# %%
# =========================
# Backup critical artifacts
# =========================

import shutil
from pathlib import Path

artifact_dir = Path("/home/ec2-user/amazon-braket-examples/examples/analog_hamiltonian_simulation/aquila_hw_tasks")

zip_base = artifact_dir.parent / "aquila_hw_tasks"
zip_path = shutil.make_archive(str(zip_base), "zip", root_dir=artifact_dir)

print("Created backup ZIP:", zip_path)
# Out:
# Created backup ZIP: /home/ec2-user/amazon-braket-examples/examples/analog_hamiltonian_simulation/aquila_hw_tasks.zip
